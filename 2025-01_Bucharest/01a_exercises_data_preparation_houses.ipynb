# %% [markdown]
# <br> </br>
# <font size = 8> <center> AI Strategy and Digital transformation </center> </font>
# <font size = 6> <center>  <b> 1. Data preparation - exercises </b> </center>
# <br>
# <font size = 5> <center> Piotr Wójcik </center> </font>
# <font size = 5> <center> University of Warsaw, Poland
# <font size = 5> <center> pwojcik@wne.uw.edu.pl
# <br> </br>
# <font size = 5> <center>  January 2025 </center> </font>
# </center> </font>

# %% [markdown]
# # Data description
#
# The data from the file `"data/houses.csv"`.
#
# The file contains data on the characteristics and prices of houses sold in the city of Ames (Iowa, USA) between 2006 and 2010.
#
# It includes 2930 observations and 81 variables.
#
# The dataset was used some time ago in the kaggle competition: [https://www.kaggle.com/c/house-prices-advanced-regression-techniques](https://www.kaggle.com/c/house-prices-advanced-regression-techniques)
#
# The task was to use data from before 2010 to build a model predicting real estate prices sold in 2010.
#
# The data have been initially pre-ordered (variable names with underscores, clearly defined individual levels of qualitative variables).
#
# The description of variables (types and definition) can be found for example here (names might be slightly different): [https://rdrr.io/cran/subgroup.discovery/man/ames.html](https://rdrr.io/cran/subgroup.discovery/man/ames.html)
#
# The detailed description of the variable levels can be found here: [http://jse.amstat.org/v19n3/decock/DataDocumentation.txt](http://jse.amstat.org/v19n3/decock/DataDocumentation.txt) and in the text file `"data/DataDocumentation.txt"` in lab materials.
#
# Identification variables
#
# * `Order`: Observation number
# * `PID`: Parcel/property identification number

# %%
# change working directory
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/My Drive/szkolenia/2025-01_Bucharest'
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/szkolenia/2025-01_Bucharest

# %%
# import all the libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, LabelEncoder
import seaborn as sns
import pickle

# %%
# import data
houses = pd.read_csv("data/houses.csv")

houses.head() # Shows the first five rows of the dataset
# Out:
#    Order        PID                          MS_SubClass  \
# 0      1  526301100  One_Story_1946_and_Newer_All_Styles
# 1      2  526350040  One_Story_1946_and_Newer_All_Styles
# 2      3  526351010  One_Story_1946_and_Newer_All_Styles
# 3      4  526353030  One_Story_1946_and_Newer_All_Styles
# 4      5  527105010             Two_Story_1946_and_Newer
#
#                   MS_Zoning  Lot_Frontage  Lot_Area Street            Alley  \
# 0   Residential_Low_Density           141     31770   Pave  No_Alley_Access
# 1  Residential_High_Density            80     11622   Pave  No_Alley_Access
# 2   Residential_Low_Density            81     14267   Pave  No_Alley_Access
# 3   Residential_Low_Density            93     11160   Pave  No_Alley_Access
# 4   Residential_Low_Density            74     13830   Pave  No_Alley_Access
#
#             Lot_Shape Land_Contour  ...            Fence Misc_Feature  \
# 0  Slightly_Irregular          Lvl  ...         No_Fence          NaN
# 1             Regular          Lvl  ...  Minimum_Privacy          NaN
# 2  Slightly_Irregular          Lvl  ...         No_Fence         Gar2
# 3             Regular          Lvl  ...         No_Fence          NaN
# 4  Slightly_Irregular          Lvl  ...  Minimum_Privacy          NaN
#
#   Misc_Val Mo_Sold Year_Sold Sale_Type Sale_Condition Sale_Price  Longitude  \
# 0        0       5      2010       WD          Normal     215000 -93.619754
# 1        0       6      2010       WD          Normal     105000 -93.619756
# 2    12500       6      2010       WD          Normal     172000 -93.619387
# 3        0       4      2010       WD          Normal     244000 -93.617320
# 4        0       3      2010       WD          Normal     189900 -93.638933
#
#     Latitude
# 0  42.054035
# 1  42.053014
# 2  42.052659
# 3  42.051245
# 4  42.060899
#
# [5 rows x 83 columns]

# %%
# the structure of the dataset
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 83 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order               2930 non-null   int64
#  1   PID                 2930 non-null   int64
#  2   MS_SubClass         2930 non-null   object
#  3   MS_Zoning           2930 non-null   object
#  4   Lot_Frontage        2930 non-null   int64
#  5   Lot_Area            2930 non-null   int64
#  6   Street              2930 non-null   object
#  7   Alley               2930 non-null   object
#  8   Lot_Shape           2930 non-null   object
#  9   Land_Contour        2930 non-null   object
#  10  Utilities           2930 non-null   object
#  11  Lot_Config          2930 non-null   object
#  12  Land_Slope          2930 non-null   object
#  13  Neighborhood        2930 non-null   object
#  14  Condition_1         2930 non-null   object
#  15  Condition_2         2930 non-null   object
#  16  Bldg_Type           2930 non-null   object
#  17  House_Style         2930 non-null   object
#  18  Overall_Qual        2930 non-null   object
#  19  Overall_Cond        2930 non-null   object
#  20  Year_Built          2930 non-null   int64
#  21  Year_Remod_Add      2930 non-null   int64
#  22  Roof_Style          2930 non-null   object
#  23  Roof_Matl           2930 non-null   object
#  24  Exterior_1st        2930 non-null   object
#  25  Exterior_2nd        2930 non-null   object
#  26  Mas_Vnr_Type        1155 non-null   object
#  27  Mas_Vnr_Area        2930 non-null   int64
#  28  Exter_Qual          2930 non-null   object
#  29  Exter_Cond          2930 non-null   object
#  30  Foundation          2930 non-null   object
#  31  Bsmt_Qual           2930 non-null   object
#  32  Bsmt_Cond           2930 non-null   object
#  33  Bsmt_Exposure       2930 non-null   object
#  34  BsmtFin_Type_1      2930 non-null   object
#  35  BsmtFin_SF_1        2930 non-null   int64
#  36  BsmtFin_Type_2      2930 non-null   object
#  37  BsmtFin_SF_2        2930 non-null   int64
#  38  Bsmt_Unf_SF         2930 non-null   int64
#  39  Total_Bsmt_SF       2930 non-null   int64
#  40  Heating             2930 non-null   object
#  41  Heating_QC          2930 non-null   object
#  42  Central_Air         2930 non-null   object
#  43  Electrical          2929 non-null   object
#  44  First_Flr_SF        2930 non-null   int64
#  45  Second_Flr_SF       2930 non-null   int64
#  46  Low_Qual_Fin_SF     2930 non-null   int64
#  47  Gr_Liv_Area         2930 non-null   int64
#  48  Bsmt_Full_Bath      2930 non-null   int64
#  49  Bsmt_Half_Bath      2930 non-null   int64
#  50  Full_Bath           2930 non-null   int64
#  51  Half_Bath           2930 non-null   int64
#  52  Bedroom_AbvGr       2930 non-null   int64
#  53  Kitchen_AbvGr       2930 non-null   int64
#  54  Kitchen_Qual        2930 non-null   object
#  55  TotRms_AbvGrd       2930 non-null   int64
#  56  Functional          2930 non-null   object
#  57  Fireplaces          2930 non-null   int64
#  58  Fireplace_Qu        2930 non-null   object
#  59  Garage_Type         2930 non-null   object
#  60  Garage_Finish       2930 non-null   object
#  61  Garage_Cars         2930 non-null   int64
#  62  Garage_Area         2930 non-null   int64
#  63  Garage_Qual         2930 non-null   object
#  64  Garage_Cond         2930 non-null   object
#  65  Paved_Drive         2930 non-null   object
#  66  Wood_Deck_SF        2930 non-null   int64
#  67  Open_Porch_SF       2930 non-null   int64
#  68  Enclosed_Porch      2930 non-null   int64
#  69  Three_season_porch  2930 non-null   int64
#  70  Screen_Porch        2930 non-null   int64
#  71  Pool_Area           2930 non-null   int64
#  72  Pool_QC             2930 non-null   object
#  73  Fence               2930 non-null   object
#  74  Misc_Feature        106 non-null    object
#  75  Misc_Val            2930 non-null   int64
#  76  Mo_Sold             2930 non-null   int64
#  77  Year_Sold           2930 non-null   int64
#  78  Sale_Type           2930 non-null   object
#  79  Sale_Condition      2930 non-null   object
#  80  Sale_Price          2930 non-null   int64
#  81  Longitude           2930 non-null   float64
#  82  Latitude            2930 non-null   float64
# dtypes: float64(2), int64(35), object(46)
# memory usage: 1.9+ MB

# %% [markdown]
# # Exercise 1.1
#
# * Check the existence of missing values and apply selected imputation method(s) for categorical and/or numerical variables.
# * Check the frequencies of individual levels of all the nominal variables and replace all the levels which have no more than 25 observations with the label "other"
#
# * Split the data into train and test samples based on a `Year_Sold`  -- use sales from 2009 and 2010 as a test sample and earlier observations as a training sample.
#
# * Drop the last two columns: Lattitude and Longitude.

# %%
# place for solution to exercise 1.1
columns_with_missings = houses.columns[houses.isnull().any()]

houses[columns_with_missings].isnull().sum()
# Out:
# Mas_Vnr_Type    1775
# Electrical         1
# Misc_Feature    2824
# dtype: int64

# %%
# frequency tables for them

print("Frequency counts for Mas_Vnr_Type: \n")
print(houses['Mas_Vnr_Type'].value_counts(dropna = False))

print("\nFrequency counts for Electrical: \n")
print(houses['Electrical'].value_counts(dropna = False))

print("\nFrequency counts for Misc_Feature: \n")
print(houses['Misc_Feature'].value_counts(dropna = False))
# Out:
# Frequency counts for Mas_Vnr_Type:
#
# Mas_Vnr_Type
# NaN        1775
# BrkFace     880
# Stone       249
# BrkCmn       25
# CBlock        1
# Name: count, dtype: int64
#
# Frequency counts for Electrical:
#
# Electrical
# SBrkr    2682
# FuseA     188
# FuseF      50
# FuseP       8
# NaN         1
# Mix         1
# Name: count, dtype: int64
#
# Frequency counts for Misc_Feature:
#
# Misc_Feature
# NaN     2824
# Shed      95
# Gar2       5
# Othr       4
# Elev       1
# TenC       1
# Name: count, dtype: int64

# %%
# according to data description the missing value in Mas_Vnr_Type and in Misc_Feature should be the value "None"
# in case of Electrical column we can replace the missing value with the most frequent level "SBrkr"

# All these can be done BEFORE the train/test aplit as they do not depend on the specific data distribution

houses['Mas_Vnr_Type'] = houses['Mas_Vnr_Type'].fillna('None')
houses['Misc_Feature'] = houses['Misc_Feature'].fillna('None')

houses['Electrical'] = houses['Electrical'].fillna('SBrkr')

# %%
# frequency tables again to check the results of imputation

print("Frequency counts for Mas_Vnr_Type: \n")
print(houses['Mas_Vnr_Type'].value_counts(dropna = False))

print("\nFrequency counts for Electrical: \n")
print(houses['Electrical'].value_counts(dropna = False))

print("\nFrequency counts for Misc_Feature: \n")
print(houses['Misc_Feature'].value_counts(dropna = False))
# Out:
# Frequency counts for Mas_Vnr_Type:
#
# Mas_Vnr_Type
# None       1775
# BrkFace     880
# Stone       249
# BrkCmn       25
# CBlock        1
# Name: count, dtype: int64
#
# Frequency counts for Electrical:
#
# Electrical
# SBrkr    2683
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# Name: count, dtype: int64
#
# Frequency counts for Misc_Feature:
#
# Misc_Feature
# None    2824
# Shed      95
# Gar2       5
# Othr       4
# Elev       1
# TenC       1
# Name: count, dtype: int64

# %%
# check for missing values after imputation

columns_with_missings = houses.columns[houses.isnull().any()]

houses[columns_with_missings].isnull().sum()

# no more missings
# Out:
# Series([], dtype: float64)

# %%
# Lets check the frequencies of individual levels of all the nominal variables
nominal_variables = ['MS_SubClass', 'MS_Zoning', 'Street', 'Alley', 'Lot_Config',
                     'Neighborhood', 'Condition_1', 'Condition_2', 'Bldg_Type',
                     'House_Style', 'Roof_Style', 'Roof_Matl', 'Exterior_1st',
                     'Exterior_2nd', 'Mas_Vnr_Type', 'Foundation', 'Misc_Feature',
                     'Heating', 'Central_Air', 'Garage_Type', 'Misc_Feature',
                     'Sale_Type', 'Sale_Condition', 'Land_Contour']

# Loop through each nominal variable
for var in nominal_variables:
    # Get the value counts for each category in the variable
    value_counts = houses[var].value_counts()
    print("\n")
    print(houses[var].value_counts(dropna = False))
# Out:
# MS_SubClass
# One_Story_1946_and_Newer_All_Styles          1079
# Two_Story_1946_and_Newer                      575
# One_and_Half_Story_Finished_All_Ages          287
# One_Story_PUD_1946_and_Newer                  192
# One_Story_1945_and_Older                      139
# Two_Story_PUD_1946_and_Newer                  129
# Two_Story_1945_and_Older                      128
# Split_or_Multilevel                           118
# Duplex_All_Styles_and_Ages                    109
# Two_Family_conversion_All_Styles_and_Ages      61
# Split_Foyer                                    48
# Two_and_Half_Story_All_Ages                    23
# One_and_Half_Story_Unfinished_All_Ages         18
# PUD_Multilevel_Split_Level_Foyer               17
# One_Story_with_Finished_Attic_All_Ages          6
# One_and_Half_Story_PUD_All_Ages                 1
# Name: count, dtype: int64
#
#
# MS_Zoning
# Residential_Low_Density         2273
# Residential_Medium_Density       462
# Floating_Village_Residential     139
# Residential_High_Density          27
# C_all                             25
# I_all                              2
# A_agr                              2
# Name: count, dtype: int64
#
#
# Street
# Pave    2918
# Grvl      12
# Name: count, dtype: int64
#
#
# Alley
# No_Alley_Access    2732
# Gravel              120
# Paved                78
# Name: count, dtype: int64
#
#
# Lot_Config
# Inside     2140
# Corner      511
# CulDSac     180
# FR2          85
# FR3          14
# Name: count, dtype: int64
#
#
# Neighborhood
# North_Ames                                 443
# College_Creek                              267
# Old_Town                                   239
# Edwards                                    194
# Somerset                                   182
# Northridge_Heights                         166
# Gilbert                                    165
# Sawyer                                     151
# Northwest_Ames                             131
# Sawyer_West                                125
# Mitchell                                   114
# Brookside                                  108
# Crawford                                   103
# Iowa_DOT_and_Rail_Road                      93
# Timberland                                  72
# Northridge                                  71
# Stone_Brook                                 51
# South_and_West_of_Iowa_State_University     48
# Clear_Creek                                 44
# Meadow_Village                              37
# Briardale                                   30
# Bloomington_Heights                         28
# Veenker                                     24
# Northpark_Villa                             23
# Blueste                                     10
# Greens                                       8
# Green_Hills                                  2
# Landmark                                     1
# Name: count, dtype: int64
#
#
# Condition_1
# Norm      2522
# Feedr      164
# Artery      92
# RRAn        50
# PosN        39
# RRAe        28
# PosA        20
# RRNn         9
# RRNe         6
# Name: count, dtype: int64
#
#
# Condition_2
# Norm      2900
# Feedr       13
# Artery       5
# PosA         4
# PosN         4
# RRNn         2
# RRAe         1
# RRAn         1
# Name: count, dtype: int64
#
#
# Bldg_Type
# OneFam      2425
# TwnhsE       233
# Duplex       109
# Twnhs        101
# TwoFmCon      62
# Name: count, dtype: int64
#
#
# House_Style
# One_Story           1481
# Two_Story            873
# One_and_Half_Fin     314
# SLvl                 128
# SFoyer                83
# Two_and_Half_Unf      24
# One_and_Half_Unf      19
# Two_and_Half_Fin       8
# Name: count, dtype: int64
#
#
# Roof_Style
# Gable      2321
# Hip         551
# Gambrel      22
# Flat         20
# Mansard      11
# Shed          5
# Name: count, dtype: int64
#
#
# Roof_Matl
# CompShg    2887
# Tar&Grv      23
# WdShake       9
# WdShngl       7
# Membran       1
# ClyTile       1
# Roll          1
# Metal         1
# Name: count, dtype: int64
#
#
# Exterior_1st
# VinylSd    1026
# MetalSd     450
# HdBoard     442
# Wd Sdng     420
# Plywood     221
# CemntBd     126
# BrkFace      88
# WdShing      56
# AsbShng      44
# Stucco       43
# BrkComm       6
# AsphShn       2
# CBlock        2
# Stone         2
# PreCast       1
# ImStucc       1
# Name: count, dtype: int64
#
#
# Exterior_2nd
# VinylSd    1015
# MetalSd     447
# HdBoard     406
# Wd Sdng     397
# Plywood     274
# CmentBd     126
# Wd Shng      81
# Stucco       47
# BrkFace      47
# AsbShng      38
# Brk Cmn      22
# ImStucc      15
# Stone         6
# AsphShn       4
# CBlock        3
# PreCast       1
# Other         1
# Name: count, dtype: int64
#
#
# Mas_Vnr_Type
# None       1775
# BrkFace     880
# Stone       249
# BrkCmn       25
# CBlock        1
# Name: count, dtype: int64
#
#
# Foundation
# PConc     1310
# CBlock    1244
# BrkTil     311
# Slab        49
# Stone       11
# Wood         5
# Name: count, dtype: int64
#
#
# Misc_Feature
# None    2824
# Shed      95
# Gar2       5
# Othr       4
# Elev       1
# TenC       1
# Name: count, dtype: int64
#
#
# Heating
# GasA     2885
# GasW       27
# Grav        9
# Wall        6
# OthW        2
# Floor       1
# Name: count, dtype: int64
#
#
# Central_Air
# Y    2734
# N     196
# Name: count, dtype: int64
#
#
# Garage_Type
# Attchd                 1731
# Detchd                  782
# BuiltIn                 186
# No_Garage               157
# Basment                  36
# More_Than_Two_Types      23
# CarPort                  15
# Name: count, dtype: int64
#
#
# Misc_Feature
# None    2824
# Shed      95
# Gar2       5
# Othr       4
# Elev       1
# TenC       1
# Name: count, dtype: int64
#
#
# Sale_Type
# WD       2536
# New       239
# COD        87
# ConLD      26
# CWD        12
# ConLI       9
# ConLw       8
# Oth         7
# Con         5
# VWD         1
# Name: count, dtype: int64
#
#
# Sale_Condition
# Normal     2413
# Partial     245
# Abnorml     190
# Family       46
# Alloca       24
# AdjLand      12
# Name: count, dtype: int64
#
#
# Land_Contour
# Lvl    2633
# HLS     120
# Bnk     117
# Low      60
# Name: count, dtype: int64

# %%
# Extremely small counts of single levels are problematic as they might be very rare cases
# which a model will not be able to learn how they influence the sale price

# Lets replace all the levels which have no more than 25 observations (ca. 1% of the sample size) with the label "other"

# IMPORTANT! Remember that for a nominal variable we can combine any levels together,
# while for an ORDINAL feature ONLY neighboring levels can be combined!

# Based on the information about the dataset we can list all nominal variables

# Loop through each nominal variable
for var in nominal_variables:
    # Get the value counts for each category in the variable
    value_counts = houses[var].value_counts()
    # Identify the levels with counts not higher than 25
    levels_to_replace = value_counts[value_counts <= 25].index
    # Replace these levels with "Other"
    houses[var] = houses[var].replace(levels_to_replace, "Other")

# %%
# Lets check the frequencies of nominal variables again
for var in nominal_variables:
    # Get the value counts for each category in the variable
    value_counts = houses[var].value_counts()
    print("\n")
    print(houses[var].value_counts(dropna = False))

# Looks like the problem with small counts has been solved
# Out:
# MS_SubClass
# One_Story_1946_and_Newer_All_Styles          1079
# Two_Story_1946_and_Newer                      575
# One_and_Half_Story_Finished_All_Ages          287
# One_Story_PUD_1946_and_Newer                  192
# One_Story_1945_and_Older                      139
# Two_Story_PUD_1946_and_Newer                  129
# Two_Story_1945_and_Older                      128
# Split_or_Multilevel                           118
# Duplex_All_Styles_and_Ages                    109
# Other                                          65
# Two_Family_conversion_All_Styles_and_Ages      61
# Split_Foyer                                    48
# Name: count, dtype: int64
#
#
# MS_Zoning
# Residential_Low_Density         2273
# Residential_Medium_Density       462
# Floating_Village_Residential     139
# Other                             29
# Residential_High_Density          27
# Name: count, dtype: int64
#
#
# Street
# Pave     2918
# Other      12
# Name: count, dtype: int64
#
#
# Alley
# No_Alley_Access    2732
# Gravel              120
# Paved                78
# Name: count, dtype: int64
#
#
# Lot_Config
# Inside     2140
# Corner      511
# CulDSac     180
# FR2          85
# Other        14
# Name: count, dtype: int64
#
#
# Neighborhood
# North_Ames                                 443
# College_Creek                              267
# Old_Town                                   239
# Edwards                                    194
# Somerset                                   182
# Northridge_Heights                         166
# Gilbert                                    165
# Sawyer                                     151
# Northwest_Ames                             131
# Sawyer_West                                125
# Mitchell                                   114
# Brookside                                  108
# Crawford                                   103
# Iowa_DOT_and_Rail_Road                      93
# Timberland                                  72
# Northridge                                  71
# Other                                       68
# Stone_Brook                                 51
# South_and_West_of_Iowa_State_University     48
# Clear_Creek                                 44
# Meadow_Village                              37
# Briardale                                   30
# Bloomington_Heights                         28
# Name: count, dtype: int64
#
#
# Condition_1
# Norm      2522
# Feedr      164
# Artery      92
# RRAn        50
# PosN        39
# Other       35
# RRAe        28
# Name: count, dtype: int64
#
#
# Condition_2
# Norm     2900
# Other      30
# Name: count, dtype: int64
#
#
# Bldg_Type
# OneFam      2425
# TwnhsE       233
# Duplex       109
# Twnhs        101
# TwoFmCon      62
# Name: count, dtype: int64
#
#
# House_Style
# One_Story           1481
# Two_Story            873
# One_and_Half_Fin     314
# SLvl                 128
# SFoyer                83
# Other                 51
# Name: count, dtype: int64
#
#
# Roof_Style
# Gable    2321
# Hip       551
# Other      58
# Name: count, dtype: int64
#
#
# Roof_Matl
# CompShg    2887
# Other        43
# Name: count, dtype: int64
#
#
# Exterior_1st
# VinylSd    1026
# MetalSd     450
# HdBoard     442
# Wd Sdng     420
# Plywood     221
# CemntBd     126
# BrkFace      88
# WdShing      56
# AsbShng      44
# Stucco       43
# Other        14
# Name: count, dtype: int64
#
#
# Exterior_2nd
# VinylSd    1015
# MetalSd     447
# HdBoard     406
# Wd Sdng     397
# Plywood     274
# CmentBd     126
# Wd Shng      81
# Other        52
# BrkFace      47
# Stucco       47
# AsbShng      38
# Name: count, dtype: int64
#
#
# Mas_Vnr_Type
# None       1775
# BrkFace     880
# Stone       249
# Other        26
# Name: count, dtype: int64
#
#
# Foundation
# PConc     1310
# CBlock    1244
# BrkTil     311
# Slab        49
# Other       16
# Name: count, dtype: int64
#
#
# Misc_Feature
# None     2824
# Shed       95
# Other      11
# Name: count, dtype: int64
#
#
# Heating
# GasA     2885
# GasW       27
# Other      18
# Name: count, dtype: int64
#
#
# Central_Air
# Y    2734
# N     196
# Name: count, dtype: int64
#
#
# Garage_Type
# Attchd       1731
# Detchd        782
# BuiltIn       186
# No_Garage     157
# Other          38
# Basment        36
# Name: count, dtype: int64
#
#
# Misc_Feature
# None     2824
# Shed       95
# Other      11
# Name: count, dtype: int64
#
#
# Sale_Type
# WD       2536
# New       239
# COD        87
# Other      42
# ConLD      26
# Name: count, dtype: int64
#
#
# Sale_Condition
# Normal     2413
# Partial     245
# Abnorml     190
# Family       46
# Other        36
# Name: count, dtype: int64
#
#
# Land_Contour
# Lvl    2633
# HLS     120
# Bnk     117
# Low      60
# Name: count, dtype: int64

# %%
# What can be still problematic hpwever is the strong concentration of variable values in one level
# (issue called: near-zero variance) - such variables have little predictive power and can be omitted

def near_zero_var(df, freq_cut=95/5, unique_cut=10):
    """
    Identifies columns with near-zero variance in a DataFrame and calculates indicators.

    Parameters:
    - df (pd.DataFrame): Input DataFrame.
    - freq_cut (float): Threshold for the frequency ratio (default = 95/5).
    - unique_cut (int): Threshold for the unique value ratio (default = 10).

    Returns:
    - pd.DataFrame: A sorted DataFrame containing:
        - variable: Column name
        - freq_ratio: Ratio of the most common value to the second most common value
        - unique_ratio: Ratio of unique values to total observations
        - high_freq_ratio: Binary indicator (1 if freq_ratio > freq_cut)
        - low_unique_ratio: Binary indicator (1 if unique_ratio < unique_cut)
    """
    results = []

    for col in df.columns:
        # Get the value counts
        counts = df[col].value_counts()

        # Calculate freq_ratio
        if len(counts) > 1:
            freq_ratio = counts.iloc[0] / counts.iloc[1]
        else:
            freq_ratio = float('inf')  # Only one unique value

        # Calculate unique_ratio
        unique_ratio = len(counts) / len(df)

        # Determine binary indicators
        high_freq_ratio = int(freq_ratio > freq_cut)
        low_unique_ratio = int(unique_ratio < unique_cut)

        # Append results
        results.append({
            'variable': col,
            'freq_ratio': freq_ratio,
            'unique_ratio': unique_ratio,
            'high_freq_ratio': high_freq_ratio,
            'low_unique_ratio': low_unique_ratio
        })

    # Convert results to a DataFrame
    results_df = pd.DataFrame(results)

    # Sort by 'high_freq_ratio' (descending) and 'low_unique_ratio' (ascending)
    results_df = results_df.sort_values(by=['freq_ratio', 'unique_ratio'], ascending=[False, True])

    return results_df


houses_nzv = near_zero_var(houses, freq_cut=97/3, unique_cut=10)

houses_nzv[(houses_nzv['low_unique_ratio'] == 1) & (houses_nzv['high_freq_ratio'] == 1)]
# Out:
#               variable   freq_ratio  unique_ratio  high_freq_ratio  \
# 71           Pool_Area  2917.000000      0.004778                1
# 10           Utilities  1463.500000      0.001024                1
# 69  Three_season_porch   964.333333      0.010580                1
# 72             Pool_QC   729.250000      0.001706                1
# 46     Low_Qual_Fin_SF   722.500000      0.012287                1
# 37        BsmtFin_SF_2   515.800000      0.093515                1
# 6               Street   243.166667      0.000683                1
# 70        Screen_Porch   205.692308      0.041297                1
# 75            Misc_Val   157.055556      0.012969                1
# 27        Mas_Vnr_Area   118.066667      0.151877                1
# 68      Enclosed_Porch   112.318182      0.062457                1
# 40             Heating   106.851852      0.001024                1
# 15         Condition_2    96.666667      0.000683                1
# 45       Second_Flr_SF    72.956522      0.216724                1
# 23           Roof_Matl    67.139535      0.000683                1
# 56          Functional    38.971429      0.002730                1
#
#     low_unique_ratio
# 71                 1
# 10                 1
# 69                 1
# 72                 1
# 46                 1
# 37                 1
# 6                  1
# 70                 1
# 75                 1
# 27                 1
# 68                 1
# 40                 1
# 15                 1
# 45                 1
# 23                 1
# 56                 1

# %%
# lets remove problematic variables from the dataset

variables_nzv = houses_nzv[(houses_nzv['low_unique_ratio'] == 1) & (houses_nzv['high_freq_ratio'] == 1)]['variable']

houses.drop(variables_nzv, axis = 1, inplace = True)

# %%
variables_nzv.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 16 entries, 71 to 56
# Series name: variable
# Non-Null Count  Dtype
# --------------  -----
# 16 non-null     object
# dtypes: object(1)
# memory usage: 256.0+ bytes

# %%
# Lets also drop Lattitude and Longitude
houses.drop(['Latitude', 'Longitude'], axis = 1, inplace = True)

# %%
# Split the data into train and test samples based on a year

houses_train = houses[houses["Year_Sold"] <= 2008]
houses_test = houses[houses["Year_Sold"] > 2008]

# check frequencies by year

print(houses_train["Year_Sold"].value_counts())

print(houses_test["Year_Sold"].value_counts())
# Out:
# Year_Sold
# 2007    694
# 2006    625
# 2008    622
# Name: count, dtype: int64
# Year_Sold
# 2009    648
# 2010    341
# Name: count, dtype: int64

# %% [markdown]
# # Exercise 1.2
#
# Check the distribution (histogram) of the dependent variable Saencoder_Price. Compare how it looks after log transformation. lets take log(x + 1) in case of zeroes

# %%
# place for solution to exercise 1.2

# Original distribution
sns.histplot(houses_train["Sale_Price"], kde = True)

# clearly right-skewed
# Out:
# <Axes: xlabel='Sale_Price', ylabel='Count'>

# %%
# Create a new object for the log-transformed Sale_Price (we do not add a new column in the dataframe)
Sale_Price_Log = np.log(houses_train["Sale_Price"] + 1)
# and plot its histogram
sns.histplot(Sale_Price_Log, kde = True)

# much more "normal-like" - probably better for modelling
# Out:
# <Axes: xlabel='Sale_Price', ylabel='Count'>

# %% [markdown]
# # Exercise 1.3
#
# Check how many unique values does each numeric variable have (qualitative variables can also be stored as numeric - e.g. as 0/1). Print frequency tables for those that have only 3-5 levels and think how it may influence the data preparation for modelling?

# %%
# place for solution to exercise 1.3

numeric_variables = houses_train.select_dtypes(include=[np.number]).columns

for col in numeric_variables:
    unique_vals = houses_train[col].unique()
    n_unique = len(unique_vals)
    print(f"Column '{col}' has {n_unique} unique values.")

    # If a column has no more than 5 unique values, print a frequency table
    if 3 <= n_unique <= 5:
        print(f"Frequency table for '{col}':")
        print(houses_train[col].value_counts(dropna = False), "\n")
# Out:
# Column 'Order' has 1941 unique values.
# Column 'PID' has 1941 unique values.
# Column 'Lot_Frontage' has 119 unique values.
# Column 'Lot_Area' has 1413 unique values.
# Column 'Year_Built' has 110 unique values.
# Column 'Year_Remod_Add' has 60 unique values.
# Column 'BsmtFin_SF_1' has 8 unique values.
# Column 'Bsmt_Unf_SF' has 938 unique values.
# Column 'Total_Bsmt_SF' has 870 unique values.
# Column 'First_Flr_SF' has 901 unique values.
# Column 'Gr_Liv_Area' has 1045 unique values.
# Column 'Bsmt_Full_Bath' has 3 unique values.
# Frequency table for 'Bsmt_Full_Bath':
# Bsmt_Full_Bath
# 0    1158
# 1     761
# 2      22
# Name: count, dtype: int64
#
# Column 'Bsmt_Half_Bath' has 3 unique values.
# Frequency table for 'Bsmt_Half_Bath':
# Bsmt_Half_Bath
# 0    1819
# 1     118
# 2       4
# Name: count, dtype: int64
#
# Column 'Full_Bath' has 4 unique values.
# Frequency table for 'Full_Bath':
# Full_Bath
# 2    1005
# 1     878
# 3      51
# 0       7
# Name: count, dtype: int64
#
# Column 'Half_Bath' has 3 unique values.
# Frequency table for 'Half_Bath':
# Half_Bath
# 0    1220
# 1     708
# 2      13
# Name: count, dtype: int64
#
# Column 'Bedroom_AbvGr' has 8 unique values.
# Column 'Kitchen_AbvGr' has 3 unique values.
# Frequency table for 'Kitchen_AbvGr':
# Kitchen_AbvGr
# 1    1859
# 2      79
# 0       3
# Name: count, dtype: int64
#
# Column 'TotRms_AbvGrd' has 13 unique values.
# Column 'Fireplaces' has 5 unique values.
# Frequency table for 'Fireplaces':
# Fireplaces
# 0    940
# 1    856
# 2    136
# 3      8
# 4      1
# Name: count, dtype: int64
#
# Column 'Garage_Cars' has 5 unique values.
# Frequency table for 'Garage_Cars':
# Garage_Cars
# 2    1052
# 1     515
# 3     258
# 0     106
# 4      10
# Name: count, dtype: int64
#
# Column 'Garage_Area' has 520 unique values.
# Column 'Wood_Deck_SF' has 306 unique values.
# Column 'Open_Porch_SF' has 230 unique values.
# Column 'Mo_Sold' has 12 unique values.
# Column 'Year_Sold' has 3 unique values.
# Frequency table for 'Year_Sold':
# Year_Sold
# 2007    694
# 2006    625
# 2008    622
# Name: count, dtype: int64
#
# Column 'Sale_Price' has 820 unique values.

# %% [markdown]
# `Bsmt_Full_Bath`, `Bsmt_Half_Bath`, `Full_Bath`, `Half_Bath`, `Fireplaces`, `Garage_Cars` are in fact counts with just few levels.
#
# Lets keep them as numeric variables not to increase the number of data dimensions. Alternatively we may consider **combining some levels** (e.g. into 0, 1 vs rest) and apply one-hot encoding.
#
#
# `Year_Sold` cannot be one-hot-encoded as its values are different in train and test samples - we keep it also as a numeric variable

# %% [markdown]
# # Exercise 1.4
#
# Check how many unique values does each ORDINAL variable have. Print frequency tables for them and think how it may influence the data preparation for modelling?

# %%
# place for solution to exercise 1.4

# List of ordinal variables based on the dataset description
# (remember that Utilities, Pool_QC and Functional columns were already removed)

ordinal_variables = [
    'Lot_Shape', 'Land_Slope', 'Exter_Qual', 'Exter_Cond', 'Bsmt_Qual', 'Bsmt_Cond',
    'Bsmt_Exposure', 'BsmtFin_Type_1', 'BsmtFin_Type_2', 'Heating_QC', 'Kitchen_Qual',
    'Fireplace_Qu', 'Garage_Finish', 'Garage_Qual', 'Garage_Cond', 'Paved_Drive',
    'Fence', 'Overall_Qual', 'Overall_Cond'
]

for col in ordinal_variables:
    unique_vals = houses_train[col].unique()
    n_unique = len(unique_vals)
    print(f"Column '{col}' has {n_unique} unique values.")
    print(f"Frequency table for '{col}':")
    print(houses_train[col].value_counts(dropna = False), "\n")
# Out:
# Column 'Lot_Shape' has 4 unique values.
# Frequency table for 'Lot_Shape':
# Lot_Shape
# Regular                 1213
# Slightly_Irregular       661
# Moderately_Irregular      55
# Irregular                 12
# Name: count, dtype: int64
#
# Column 'Land_Slope' has 3 unique values.
# Frequency table for 'Land_Slope':
# Land_Slope
# Gtl    1850
# Mod      81
# Sev      10
# Name: count, dtype: int64
#
# Column 'Exter_Qual' has 4 unique values.
# Frequency table for 'Exter_Qual':
# Exter_Qual
# Typical      1201
# Good          658
# Excellent      65
# Fair           17
# Name: count, dtype: int64
#
# Column 'Exter_Cond' has 5 unique values.
# Frequency table for 'Exter_Cond':
# Exter_Cond
# Typical      1704
# Good          187
# Fair           41
# Excellent       8
# Poor            1
# Name: count, dtype: int64
#
# Column 'Bsmt_Qual' has 6 unique values.
# Frequency table for 'Bsmt_Qual':
# Bsmt_Qual
# Typical        847
# Good           817
# Excellent      168
# Fair            57
# No_Basement     50
# Poor             2
# Name: count, dtype: int64
#
# Column 'Bsmt_Cond' has 6 unique values.
# Frequency table for 'Bsmt_Cond':
# Bsmt_Cond
# Typical        1723
# Good             93
# Fair             70
# No_Basement      50
# Excellent         3
# Poor              2
# Name: count, dtype: int64
#
# Column 'Bsmt_Exposure' has 5 unique values.
# Frequency table for 'Bsmt_Exposure':
# Bsmt_Exposure
# No             1227
# Av              292
# Gd              203
# Mn              167
# No_Basement      52
# Name: count, dtype: int64
#
# Column 'BsmtFin_Type_1' has 7 unique values.
# Frequency table for 'BsmtFin_Type_1':
# BsmtFin_Type_1
# Unf            577
# GLQ            549
# ALQ            292
# Rec            197
# BLQ            172
# LwQ            104
# No_Basement     50
# Name: count, dtype: int64
#
# Column 'BsmtFin_Type_2' has 7 unique values.
# Frequency table for 'BsmtFin_Type_2':
# BsmtFin_Type_2
# Unf            1666
# Rec              68
# LwQ              61
# No_Basement      50
# BLQ              40
# ALQ              33
# GLQ              23
# Name: count, dtype: int64
#
# Column 'Heating_QC' has 5 unique values.
# Frequency table for 'Heating_QC':
# Heating_QC
# Excellent    993
# Typical      553
# Good         333
# Fair          59
# Poor           3
# Name: count, dtype: int64
#
# Column 'Kitchen_Qual' has 4 unique values.
# Frequency table for 'Kitchen_Qual':
# Kitchen_Qual
# Typical      994
# Good         771
# Excellent    132
# Fair          44
# Name: count, dtype: int64
#
# Column 'Fireplace_Qu' has 6 unique values.
# Frequency table for 'Fireplace_Qu':
# Fireplace_Qu
# No_Fireplace    940
# Good            504
# Typical         388
# Fair             50
# Poor             31
# Excellent        28
# Name: count, dtype: int64
#
# Column 'Garage_Finish' has 4 unique values.
# Frequency table for 'Garage_Finish':
# Garage_Finish
# Unf          813
# RFn          536
# Fin          485
# No_Garage    107
# Name: count, dtype: int64
#
# Column 'Garage_Qual' has 6 unique values.
# Frequency table for 'Garage_Qual':
# Garage_Qual
# Typical      1719
# No_Garage     107
# Fair           89
# Good           20
# Poor            4
# Excellent       2
# Name: count, dtype: int64
#
# Column 'Garage_Cond' has 6 unique values.
# Frequency table for 'Garage_Cond':
# Garage_Cond
# Typical      1758
# No_Garage     107
# Fair           50
# Good           14
# Poor           10
# Excellent       2
# Name: count, dtype: int64
#
# Column 'Paved_Drive' has 3 unique values.
# Frequency table for 'Paved_Drive':
# Paved_Drive
# Paved               1751
# Dirt_Gravel          147
# Partial_Pavement      43
# Name: count, dtype: int64
#
# Column 'Fence' has 5 unique values.
# Frequency table for 'Fence':
# Fence
# No_Fence             1576
# Minimum_Privacy       210
# Good_Privacy           76
# Good_Wood              69
# Minimum_Wood_Wire      10
# Name: count, dtype: int64
#
# Column 'Overall_Qual' has 10 unique values.
# Frequency table for 'Overall_Qual':
# Overall_Qual
# Average           554
# Above_Average     486
# Good              397
# Very_Good         238
# Below_Average     141
# Excellent          68
# Fair               26
# Very_Excellent     23
# Poor                5
# Very_Poor           3
# Name: count, dtype: int64
#
# Column 'Overall_Cond' has 9 unique values.
# Frequency table for 'Overall_Cond':
# Overall_Cond
# Average          1101
# Above_Average     355
# Good              260
# Very_Good          94
# Below_Average      69
# Fair               30
# Excellent          25
# Very_Poor           4
# Poor                3
# Name: count, dtype: int64

# %% [markdown]
# # Exercise 1.5
#
# Apply level encoding on all ordinal predictors and one-hot encoding on all nominal predictors

# %%
# place for solution to exercise 1.5

# lets start with the ordinal variables

# For each of them we define a correct order (based on the data description file)

Lot_Shape_order = ['Regular', 'Slightly_Irregular', 'Moderately_Irregular','Irregular']
Land_Slope_order = ['Gtl', 'Mod', 'Sev']
Overall_Qual_Cond_order =  ['Very_Excellent', 'Excellent', 'Very_Good', 'Good', 'Above_Average', 'Average',
                            'Below_Average', 'Fair','Poor', 'Very_Poor'] # Overall_Qual and Overall_Comd
# for Exter_Qual, Exter_Cond, Heating_QC, Kitchen_Qual
Qual_Cond_order = ['Excellent', 'Good', 'Typical', 'Fair', 'Poor']
Bsmt_Qual_Cond_order = ['Excellent', 'Good', 'Typical', 'Fair', 'Poor', 'No_Basement']
Fireplace_Qu_order = ['Excellent', 'Good', 'Typical', 'Fair', 'Poor', 'No_Fireplace']
Garage_Qual_Cond_order = ['Excellent', 'Good', 'Typical', 'Fair', 'Poor', 'No_Garage']
Bsmt_Exposure_order = ['Gd', 'Av', 'Mn', 'No', 'No_Basement']
BsmtFin_Type_1_2_order = ['GLQ', 'ALQ', 'BLQ', 'Rec', 'LwQ', 'Unf', 'No_Basement']
Electrical_order = ['SBrkr', 'FuseA', 'FuseF', 'FuseP', 'Mix']
Garage_Finish_order = ['Fin', 'RFn', 'Unf', 'No_Garage']
Paved_Drive_order = ['Paved', 'Partial_Pavement', 'Dirt_Gravel' ]
Fence_order = ['Good_Privacy', 'Minimum_Privacy', 'Good_Wood', 'Minimum_Wood_Wire', 'No_Fence']

# list of variables to include in the ordinal encoder
ordinal_variables_to_transform = ['Lot_Shape', 'Land_Slope', 'Overall_Qual', 'Overall_Cond',
                                  'Exter_Qual', 'Exter_Cond', 'Heating_QC', 'Kitchen_Qual',
                                  'Bsmt_Qual', 'Bsmt_Cond', 'Fireplace_Qu', 'Garage_Qual',
                                  'Garage_Cond', 'Bsmt_Exposure', 'BsmtFin_Type_1', 'BsmtFin_Type_2',
                                  'Electrical', 'Garage_Finish', 'Paved_Drive', 'Fence']

# Initialize OrdinalEncoder providing a list of categories for each of the
# variables which will be transformed

# if categories is an array, it has to be of shape (n_features,)
encoder_ord = OrdinalEncoder(categories = [Lot_Shape_order,         # Lot_Shape
                                           Land_Slope_order,        # Land_Slope
                                           Overall_Qual_Cond_order, # Overall_Qual
                                           Overall_Qual_Cond_order, # Overall_Cond
                                           Qual_Cond_order,         # Exter_Qual
                                           Qual_Cond_order,         # Exter_Cond
                                           Qual_Cond_order,         # Heating_QC
                                           Qual_Cond_order,         # Kitchen_Qual
                                           Bsmt_Qual_Cond_order,    # Bsmt_Qual
                                           Bsmt_Qual_Cond_order,    # Bsmt_Cond
                                           Fireplace_Qu_order,      # Fireplace_Qu
                                           Garage_Qual_Cond_order,  # Garage_Qual
                                           Garage_Qual_Cond_order,  # Garage_Cond
                                           Bsmt_Exposure_order,     # Bsmt_Exposure
                                           BsmtFin_Type_1_2_order,  # BsmtFin_Type_1
                                           BsmtFin_Type_1_2_order,  # BsmtFin_Type_2
                                           Electrical_order,        # Electrical
                                           Garage_Finish_order,     # Garage_Finish
                                           Paved_Drive_order,       # Paved_Drive
                                           Fence_order],            # Fence
                              handle_unknown = 'use_encoded_value', # just in case any new value appears
                              unknown_value = -1)  # Encodes unknown categories as -1

# Apply to training data (variables in the same order as the lists of categories above)

# houses_train.loc[:, columns] explicitly references the DataFrame slice where the assignment will occur,
# making it clear to pandas that you're modifying the original DataFrame.
# The : indicates all rows, while the list of columns specifies the exact columns to update.

houses_train.loc[:, ordinal_variables_to_transform] = encoder_ord.fit_transform(houses_train[ordinal_variables_to_transform])

# Apply transform for the test data using the same fitted encoder
houses_test.loc[:, ordinal_variables_to_transform] = encoder_ord.transform(houses_test[ordinal_variables_to_transform])

# Check the result
houses_test.head()
# Out:
#    Order        PID                          MS_SubClass  \
# 0      1  526301100  One_Story_1946_and_Newer_All_Styles
# 1      2  526350040  One_Story_1946_and_Newer_All_Styles
# 2      3  526351010  One_Story_1946_and_Newer_All_Styles
# 3      4  526353030  One_Story_1946_and_Newer_All_Styles
# 4      5  527105010             Two_Story_1946_and_Newer
#
#                   MS_Zoning  Lot_Frontage  Lot_Area            Alley  \
# 0   Residential_Low_Density           141     31770  No_Alley_Access
# 1  Residential_High_Density            80     11622  No_Alley_Access
# 2   Residential_Low_Density            81     14267  No_Alley_Access
# 3   Residential_Low_Density            93     11160  No_Alley_Access
# 4   Residential_Low_Density            74     13830  No_Alley_Access
#
#   Lot_Shape Land_Contour Lot_Config  ... Paved_Drive Wood_Deck_SF  \
# 0       1.0          Lvl     Corner  ...         1.0          210
# 1       0.0          Lvl     Inside  ...         0.0          140
# 2       1.0          Lvl     Corner  ...         0.0          393
# 3       0.0          Lvl     Corner  ...         0.0            0
# 4       1.0          Lvl     Inside  ...         0.0          212
#
#   Open_Porch_SF Fence Misc_Feature Mo_Sold Year_Sold  Sale_Type  \
# 0            62   4.0         None       5      2010        WD
# 1             0   1.0         None       6      2010        WD
# 2            36   4.0        Other       6      2010        WD
# 3             0   4.0         None       4      2010        WD
# 4            34   1.0         None       3      2010        WD
#
#    Sale_Condition Sale_Price
# 0          Normal     215000
# 1          Normal     105000
# 2          Normal     172000
# 3          Normal     244000
# 4          Normal     189900
#
# [5 rows x 65 columns]

# %%
# now we transform the nominal variables

# lets exlude from the list those which had nzv
# !! variables_nzv is pandas.core.series.Series - we need a list below
nominal_variables_left = [var for var in nominal_variables if var not in variables_nzv.tolist()]

# lets apply one-hot-encoding using the pandas get_dummies()
# train
houses_train = pd.get_dummies(houses_train,
                              columns = nominal_variables_left,
                              drop_first = True,
                              dtype = int) # bool by default

# test
houses_test = pd.get_dummies(houses_test,
                             columns = nominal_variables_left,
                             drop_first = True,
                             dtype = int)

houses_test.head()
# Out:
#    Order        PID  Lot_Frontage  Lot_Area Lot_Shape Land_Slope Overall_Qual  \
# 0      1  526301100           141     31770       1.0        0.0          4.0
# 1      2  526350040            80     11622       0.0        0.0          5.0
# 2      3  526351010            81     14267       1.0        0.0          4.0
# 3      4  526353030            93     11160       0.0        0.0          3.0
# 4      5  527105010            74     13830       1.0        0.0          5.0
#
#   Overall_Cond  Year_Built  Year_Remod_Add  ... Sale_Type_New Sale_Type_Other  \
# 0          5.0        1960            1960  ...             0               0
# 1          4.0        1961            1961  ...             0               0
# 2          4.0        1958            1958  ...             0               0
# 3          5.0        1968            1968  ...             0               0
# 4          5.0        1997            1998  ...             0               0
#
#   Sale_Type_WD  Sale_Condition_Family Sale_Condition_Normal  \
# 0             1                     0                     1
# 1             1                     0                     1
# 2             1                     0                     1
# 3             1                     0                     1
# 4             1                     0                     1
#
#   Sale_Condition_Other  Sale_Condition_Partial Land_Contour_HLS  \
# 0                    0                       0                0
# 1                    0                       0                0
# 2                    0                       0                0
# 3                    0                       0                0
# 4                    0                       0                0
#
#    Land_Contour_Low  Land_Contour_Lvl
# 0                 0                 1
# 1                 0                 1
# 2                 0                 1
# 3                 0                 1
# 4                 0                 1
#
# [5 rows x 154 columns]

# %% [markdown]
# # Exercise 1.6
#
# Save the final `houses_train` and `houses_test` datasets as pickles (`*.pkl`) into the `"data"` folder for further analyses.

# %%
# place for solution to exercise 1.6

# Let's save the final datasets for further steps into pickle files
# 'wb' stands for write in a binary mode

with open("outputs/houses_prepared.pkl", "wb") as f:
    pickle.dump(houses_train, f)
    pickle.dump(houses_test, f)

# %%
# Let's save the final datasets also to csv's for further steps
houses_train.to_csv("outputs/houses_train_prepared.csv",
                    sep = ',',
                    encoding = 'utf-8',
                    index = False,
                    header = True)

houses_test.to_csv("outputs/houses_test_prepared.csv",
                   sep = ',',
                   encoding = 'utf-8',
                   index = False,
                   header = True)
